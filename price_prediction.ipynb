# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("data.csv")

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
# CRIM       506 non-null float64
# ZN         506 non-null float64
# INDUS      506 non-null float64
# CHAS       506 non-null int64
# NOX        506 non-null float64
# RM         500 non-null float64
# AGE        506 non-null float64
# DIS        506 non-null float64
# RAD        506 non-null int64
# TAX        506 non-null int64
# PTRATIO    506 non-null float64
# B          506 non-null float64
# LSTAT      506 non-null float64
# MEDV       506 non-null float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
df.isnull().count()
# Out:
# CRIM       506
# ZN         506
# INDUS      506
# CHAS       506
# NOX        506
# RM         506
# AGE        506
# DIS        506
# RAD        506
# TAX        506
# PTRATIO    506
# B          506
# LSTAT      506
# MEDV       506
# dtype: int64

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  500.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284050
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.706263
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.883000
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.205000
# 75%      3.677082   12.500000   18.100000    0.000000    0.624000    6.626000
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
df.plot(kind="hist")

# %%
df.hist(bins=50 ,figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001C1B51DF548>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C1B5238208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C1B5266D48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C1B529EE88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C1B52D7F88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C1B53120C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C1B5344148>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C1B537C248>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C1B5384E08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C1B53BBFC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C1B5425588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C1B5464E48>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C1B5498788>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C1B54D0888>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C1B5508988>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C1B5542B88>]],
#       dtype=object)

# %%
df.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219307  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311461 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.394346  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091592  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302631  0.731470
# RM      -0.219307  0.311461 -0.394346  0.091592 -0.302631  1.000000 -0.240182
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240182  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.203307 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.210535  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292709  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.357679  0.261515
# B       -0.385064  0.175520 -0.356977  0.048788 -0.380051  0.127964 -0.273534
# LSTAT    0.455621 -0.412995  0.603800 -0.053929  0.590879 -0.615983  0.602339
# MEDV    -0.388305  0.360445 -0.483725  0.175260 -0.427321  0.696232 -0.376955
#
#               DIS       RAD       TAX   PTRATIO         B     LSTAT      MEDV
# CRIM    -0.379670  0.625505  0.582764  0.289946 -0.385064  0.455621 -0.388305
# ZN       0.664408 -0.311948 -0.314563 -0.391679  0.175520 -0.412995  0.360445
# INDUS   -0.708027  0.595129  0.720760  0.383248 -0.356977  0.603800 -0.483725
# CHAS    -0.099176 -0.007368 -0.035587 -0.121515  0.048788 -0.053929  0.175260
# NOX     -0.769230  0.611441  0.668023  0.188933 -0.380051  0.590879 -0.427321
# RM       0.203307 -0.210535 -0.292709 -0.357679  0.127964 -0.615983  0.696232
# AGE     -0.747881  0.456022  0.506456  0.261515 -0.273534  0.602339 -0.376955
# DIS      1.000000 -0.494588 -0.534432 -0.232471  0.291512 -0.496996  0.249929
# RAD     -0.494588  1.000000  0.910228  0.464741 -0.444413  0.488676 -0.381626
# TAX     -0.534432  0.910228  1.000000  0.460853 -0.441808  0.543993 -0.468536
# PTRATIO -0.232471  0.464741  0.460853  1.000000 -0.177383  0.374044 -0.507787
# B        0.291512 -0.444413 -0.441808 -0.177383  1.000000 -0.366087  0.333461
# LSTAT   -0.496996  0.488676  0.543993  0.374044 -0.366087  1.000000 -0.737663
# MEDV     0.249929 -0.381626 -0.468536 -0.507787  0.333461 -0.737663  1.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,12))
ax=sns.heatmap(df.corr(),annot=True,square=True,cmap='coolwarm',annot_kws={'size':8.0})

# %%
from sklearn.model_selection import train_test_split
train_set, test_set  = train_test_split(df, test_size=0.2, random_state=42)
print(f"Rows in train set: {len(train_set)}\nRows in test set: {len(test_set)}\n")
# Out:
# Rows in train set: 404
# Rows in test set: 102

# %%
cross_matrix=df.corr()
cross_matrix['MEDV'].sort_values(ascending=False)
# Out:
# MEDV       1.000000
# RM         0.696232
# ZN         0.360445
# B          0.333461
# DIS        0.249929
# CHAS       0.175260
# AGE       -0.376955
# RAD       -0.381626
# CRIM      -0.388305
# NOX       -0.427321
# TAX       -0.468536
# INDUS     -0.483725
# PTRATIO   -0.507787
# LSTAT     -0.737663
# Name: MEDV, dtype: float64

# %%
from sklearn.model_selection import StratifiedShuffleSplit
split=StratifiedShuffleSplit(n_splits=1,test_size=0.2,random_state=42)

# %%
for train_index, test_index in split.split(df,df["CHAS"]):
    strat_train_set = df.loc[train_index]
    strat_test_set = df.loc[test_index]

# %%
strat_train_set['CHAS'].value_counts()
# Out:
# 0    376
# 1     28
# Name: CHAS, dtype: int64

# %%
strat_test_set['CHAS'].value_counts()
# Out:
# 0    95
# 1     7
# Name: CHAS, dtype: int64

# %%
df=strat_train_set.copy()

# %%
cross_matrix=df.corr()

# %%
cross_matrix['MEDV'].sort_values(ascending=False)
# Out:
# MEDV       1.000000
# RM         0.680915
# B          0.361761
# ZN         0.339741
# DIS        0.240451
# CHAS       0.205066
# AGE       -0.364596
# RAD       -0.374693
# CRIM      -0.393715
# NOX       -0.422873
# TAX       -0.456657
# INDUS     -0.473516
# PTRATIO   -0.493534
# LSTAT     -0.740494
# Name: MEDV, dtype: float64

# %%
from pandas.plotting import scatter_matrix
attributes=["MEDV","RM","ZN","LSTAT"]
scatter_matrix(df[attributes],figsize=(12,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001C1B8E65F88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C1B8EAE1C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C1B8EE5248>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C1B8F1D348>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C1B8F54448>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C1B8F8E548>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C1B8FCDE88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C1B9000788>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C1B900B388>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C1B9043508>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C1B90A9A88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C1B90E1B88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C1B911BCC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C1B9153DC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C1B9189E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C1B91C3F88>]],
#       dtype=object)

# %%
df.plot(kind="scatter",x="RM",y="MEDV",alpha=0.8)

# %%
df["TAXRM"] = df['TAX']/df['RM']

# %%
cross_matrix=df.corr()

# %%
cross_matrix['MEDV'].sort_values(ascending=False)
# Out:
# MEDV       1.000000
# RM         0.680915
# B          0.361761
# ZN         0.339741
# DIS        0.240451
# CHAS       0.205066
# AGE       -0.364596
# RAD       -0.374693
# CRIM      -0.393715
# NOX       -0.422873
# TAX       -0.456657
# INDUS     -0.473516
# PTRATIO   -0.493534
# TAXRM     -0.527916
# LSTAT     -0.740494
# Name: MEDV, dtype: float64

# %%
df.plot(kind="scatter",x="RM",y="MEDV")

# %%
df.isnull().count()
# Out:
# CRIM       404
# ZN         404
# INDUS      404
# CHAS       404
# NOX        404
# RM         404
# AGE        404
# DIS        404
# RAD        404
# TAX        404
# PTRATIO    404
# B          404
# LSTAT      404
# MEDV       404
# TAXRM      404
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 404 entries, 254 to 216
# Data columns (total 15 columns):
# CRIM       404 non-null float64
# ZN         404 non-null float64
# INDUS      404 non-null float64
# CHAS       404 non-null int64
# NOX        404 non-null float64
# RM         398 non-null float64
# AGE        404 non-null float64
# DIS        404 non-null float64
# RAD        404 non-null int64
# TAX        404 non-null int64
# PTRATIO    404 non-null float64
# B          404 non-null float64
# LSTAT      404 non-null float64
# MEDV       404 non-null float64
# TAXRM      398 non-null float64
# dtypes: float64(12), int64(3)
# memory usage: 50.5 KB

# %%
median=df['RM'].median()
median=df['TAXRM'].median()

# %%
df['RM'].fillna(median)
# Out:
# 254    6.108
# 348    6.635
# 476    6.484
# 321    6.376
# 326    6.312
#        ...
# 155    6.152
# 423    6.103
# 98     7.820
# 455    6.525
# 216    5.888
# Name: RM, Length: 404, dtype: float64

# %%
df['TAXRM'].fillna(median)
# Out:
# 254     51.571709
# 348     42.200452
# 476    102.714374
# 321     45.012547
# 326     45.468948
#           ...
# 155     65.507152
# 423    109.126659
# 98      35.294118
# 455    102.068966
# 216     46.875000
# Name: TAXRM, Length: 404, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 404 entries, 254 to 216
# Data columns (total 15 columns):
# CRIM       404 non-null float64
# ZN         404 non-null float64
# INDUS      404 non-null float64
# CHAS       404 non-null int64
# NOX        404 non-null float64
# RM         398 non-null float64
# AGE        404 non-null float64
# DIS        404 non-null float64
# RAD        404 non-null int64
# TAX        404 non-null int64
# PTRATIO    404 non-null float64
# B          404 non-null float64
# LSTAT      404 non-null float64
# MEDV       404 non-null float64
# TAXRM      398 non-null float64
# dtypes: float64(12), int64(3)
# memory usage: 50.5 KB

# %%
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(strategy="median")
imputer.fit(df)
# Out:
# SimpleImputer(add_indicator=False, copy=True, fill_value=None,
#               missing_values=nan, strategy='median', verbose=0)

# %%
imputer.statistics_
# Out:
# array([2.86735000e-01, 0.00000000e+00, 9.90000000e+00, 0.00000000e+00,
#        5.38000000e-01, 6.20900000e+00, 7.82000000e+01, 3.12220000e+00,
#        5.00000000e+00, 3.37000000e+02, 1.90000000e+01, 3.90955000e+02,
#        1.15700000e+01, 2.11500000e+01, 5.50305984e+01])

# %%
X=imputer.transform(df)

# %%
housing_tr = pd.DataFrame(X, columns=df.columns)

# %%
housing_tr.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean     3.602814   10.836634   11.344950    0.069307    0.558064    6.278062
# std      8.099383   22.150636    6.877817    0.254290    0.116875    0.712334
# min      0.006320    0.000000    0.740000    0.000000    0.389000    3.561000
# 25%      0.086963    0.000000    5.190000    0.000000    0.453000    5.878750
# 50%      0.286735    0.000000    9.900000    0.000000    0.538000    6.209000
# 75%      3.731923   12.500000   18.100000    0.000000    0.631000    6.630000
# max     73.534100  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean    69.039851    3.746210    9.735149  412.341584   18.473267  353.392822
# std     28.258248    2.099057    8.731259  168.672623    2.129243   96.069235
# min      2.900000    1.129600    1.000000  187.000000   13.000000    0.320000
# 25%     44.850000    2.035975    4.000000  284.000000   17.400000  374.617500
# 50%     78.200000    3.122200    5.000000  337.000000   19.000000  390.955000
# 75%     94.100000    5.100400   24.000000  666.000000   20.200000  395.630000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV       TAXRM
# count  404.000000  404.000000  404.000000
# mean    12.791609   22.509406   67.590009
# std      7.235740    9.385531   31.374994
# min      1.730000    5.000000   24.645639
# 25%      6.847500   16.600000   45.168593
# 50%     11.570000   21.150000   55.030598
# 75%     17.102500   25.000000   98.317507
# max     36.980000   50.000000  187.026116

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
my_pipeline=Pipeline([('imputer',SimpleImputer(strategy='median')),('std_sclaer',StandardScaler()),])

# %%
df=df.drop('TAX',axis=1)

# %%
df = strat_train_set.drop("MEDV", axis=1)
housing_labels = strat_train_set["MEDV"].copy()

# %%
house_num_tr=my_pipeline.fit_transform(df)

# %%
house_num_tr.shape
# Out:
# (404, 13)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
model=RandomForestRegressor()

# %%
model.fit(house_num_tr,housing_labels)
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
some_data=df.iloc[:5]
some_labels=housing_labels[:5]

# %%
prepared_data=my_pipeline.fit_transform(some_data)

# %%
pred=model.predict(prepared_data)

# %%
some_labels.shape
# Out:
# (5,)

# %%
from sklearn.metrics import mean_squared_error
housing_predictions = model.predict(house_num_tr)
mse = mean_squared_error(housing_labels, housing_predictions)
rmse = np.sqrt(mse)

# %%
print(rmse)
# Out:
# 1.4416435546326494

# %%
from sklearn.model_selection import cross_val_score

# %%
scores=cross_val_score(model,house_num_tr,housing_labels,scoring="neg_mean_squared_error",cv=10)

# %%
rmse=np.sqrt(-scores)

# %%
def print_scores(scores):
    print("Scores:", scores)
    print("Mean: ", scores.mean())
    print("Standard deviation: ", scores.std())

# %%
print_scores(rmse)
# Out:
# Scores: [2.68678972 2.8534549  4.13511465 2.50976337 3.46307053 2.53425975
#  3.81932422 3.70680219 2.75140419 4.00346194]
# Mean:  3.24634454756564
# Standard deviation:  0.6093014486443541

# %%
from joblib import dump, load

# %%
dump(model,"dragon.joblib")
# Out:
# ['dragon.joblib']

# %% [markdown]
# # testing the model with test set

# %%
df=strat_test_set.drop("MEDV",axis=1)
housing_labels=strat_test_set["MEDV"].copy()
X_test_prepared = my_pipeline.transform(df)
final_predictions = model.predict(X_test_prepared)

# %%
final_mse = mean_squared_error(housing_labels, final_predictions)
final_rmse = np.sqrt(final_mse)

# %%
print(final_rmse)
# Out:
# 7.005132292210657

# %%
from joblib import dump, load
import numpy as np
model = load('Dragon.joblib') 
features = np.array([[-5.43942006, 4.12628155, -1.6165014, -0.67288841, -1.42262747,
       -11.44443979304, -49.31238772,  7.61111401, -26.0016879 , -0.5778192 ,
       -0.97491834,  0.41164221, -66.86091034]])
model.predict(features)
# Out:
# array([25.8])
